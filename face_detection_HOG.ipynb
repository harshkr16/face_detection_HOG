# %%
from imutils import face_utils
import dlib
import cv2
import matplotlib.pyplot as plt
def detectdlib(imgpath):
    frame=cv2.imread(imgpath)
    frame=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
    gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
    face_detects=dlib.get_frontal_face_detector()
    rects=face_detects(gray,1)
    for (i,rect) in enumerate(rects):
        (x,y,w,h)=face_utils.rect_to_bb(rect)
        cv2.rectangle(frame, (x,y), (x+w,y+h),(255,255,255),3)
    plt.imshow(frame)
    plt.show()

# %%
detectdlib("face-match.jpg")
detectdlib("ratan_tata.jpg")
detectdlib("ratan_tata1.jpg")
detectdlib("group-photo.jpg")

# %%
detectdlib("group-selfie.jpeg")

# %%
detectdlib("home_photo.jpg")
